# %% [markdown]
# # Data Science 2 - ESEO DSMT
# ## Principal Components Analysis (PCA)
# ### 23 Nov 2021  -- Prof. R. LONGO
#
# 1. PCA Algorithm (From Linear Algebra)
# 2. Principal Component Analysis with scikit-learn
# 3. Data Visualization
# 4. Dimension Reduction (Pixel Data)
# 5. Dimension Reduction (Sequential Data or Time Series Analysis)

# %% [markdown]
# #### 1. PCA Algorithm (From Linear Algebra)

# %% [markdown]
# Given a Data Base $X_{N*d}$ we want to calculate:
# Xpca = PCA(X)
# 1. The first step is to calculate the mean values of each column
# $M = mean(X)$
# 2. Next, we need to center the values in each column by subtracting the mean column value.
# C = X − M
# 3. The next step is to estimate the covariance matrix of the centered matrix C.
# \
# $\hat{\Sigma}_{d*d} = cov(C)$
#
# 4. Finally, we calculate the eigendecomposition  of the covariance matrix $\hat{\Sigma}_{d*d}$. This results in a list of eigenvalues $\lambda$ and a list of eigenvectors $V_{d*d}$.
# \
#    $\lambda, V = eig(\hat{\Sigma}) $
#    \
# Ideally, we would select k eigenvectors called Principal Components, that have the k largest eigenvalues and store them in a matrix $W$.Once chosen, data can be projected into the Principal Components subspace via matrix multiplication:
#  $Xpca _{N*k} = C_{N*d}.W_{d*k}$

# %%
import numpy as np
import matplotlib.pyplot as plt

from numpy import array
from numpy import mean
from numpy import cov
from numpy.linalg import eig
# %matplotlib notebook

# %%
# First generate some data
mu = np.array([0,0])
seed =0
np.random.seed(seed=seed)

Sigma = np.array([[ 40,  25],
       [ 25,  16]])
X = np.random.multivariate_normal(mu,Sigma,20000)
fig = plt.figure(figsize=[5,5])
plt.scatter(X[:,0],X[:,1]);
print(X.shape)
# Out:
# <img src="data:image/png;base64,..." width="500">
# (20000, 2)

# %%
# Step 1 and 2
M = np.mean(X,axis=0)
print(M.shape)
C = X-M
# Out:
# (2,)

# %%
sigma_hat = cov(C,rowvar=False)

# %%
#step 4 
lamb, V = np.linalg.eig(sigma_hat)
print("Eigen Value :",lamb)
print("Eigen Vector :\n",V)
# Out:
# Eigen Value : [55.69393413  0.26578852]
# Eigen Vector :
#  [[ 0.84684208 -0.53184443]
#  [ 0.53184443  0.84684208]]

# %%
v1 = V[:,0].reshape(-1,1)
v2 = V[:,1].reshape(-1,1)

print("Vecteurs orthogonaux? ","Vrai" if v1.T.dot(v2)==0 else "Faux")
print("Vecteurs orthogonaux? ","Vrai" if v2.T.dot(v1)==0 else "Faux")
# Out:
# Vecteurs orthogonaux?  Vrai
# Vecteurs orthogonaux?  Vrai

# %%
# first plot the eigenvectors
ah=1 # size of arrow head

 

plt.figure(figsize=(8,8))
plt.scatter(X[:,0],X[:,1],c='b',alpha=0.2)
plt.axis('equal')
plt.grid()
plt.title('Principal Components (eigenvectors) of random data', fontsize=12)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)

 

plt.arrow(0,0,v1[0][0]*(lamb[0]),v1[1][0]*(lamb[0]),color='r',head_width=ah,head_length=ah)
plt.arrow(0,0,v2[0][0]*(lamb[1]),v2[1][0]*(lamb[1]),color='r',head_width=ah,head_length=ah)

# %%
# step 4 (encore)
W = V 
Xpca = np.dot(C,W)
Xpca.shape
plt.figure(figsize=(5,5))
plt.axis("equal")
plt.plot(Xpca[:,0],Xpca[:,1],'o')
plt.xlabel("PC1")
plt.ylabel("PC2")
# Out:
# Text(0, 0.5, 'PC2')

# %%
#dimension reduction
W = V[:,0]
Xpca = np.dot(C,W)

plt.figure(figsize=(5,5))
plt.axis('equal')
plt.plot(Xpca,np.zeros([len(Xpca)]),'o');
plt.xlabel('PC1');

# %% [markdown]
#  #### 2. Principal Component Analysis with scikit-learn

# %%
from sklearn.decomposition import PCA

# %%
model = PCA()

# %%
Xpca = model.fit_transform(C)

# %%
print(model.components_.T)
# Out:
# [[ 0.84684208 -0.53184443]
#  [ 0.53184443  0.84684208]]

# %%
print(model.explained_variance_)
# Out:
# [55.69393413  0.26578852]

# %%
## Attention: Normalement on standardise les données avant d'appliquer la PCA (mu = 0 et Sigma = 1)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
preprocessor = make_pipeline(StandardScaler(), PCA())
Xpca = preprocessor.fit_transform(X)

# %%
print(preprocessor[1].explained_variance_)
print(preprocessor[1].components_.T)
# Out:
# [1.98843064 0.01166937]
# [[ 0.70710678  0.70710678]
#  [ 0.70710678 -0.70710678]]

# %% [markdown]
# #### 3. Data Visualization

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()
X = digits.data
y = digits.target

# %%
model = PCA(n_components = 2)
Xpca = model.fit_transform(X)
Xpca.shape
# Out:
# (1797, 2)

# %%
plt.scatter(Xpca[:,0],Xpca[:,1],c=y)

# %% [markdown]
# #### 4. Dimension Reduction

# %%
model = PCA(n_components = 64)
Xpca= model.fit_transform(X)

# %%
model.explained_variance_ratio_;

# %%
plt.plot(np.cumsum(model.explained_variance_ratio_),'o')
plt.xlabel("PC")
plt.ylabel("Info %")
# Out:
# Text(0, 0.5, 'Info %')

# %% [markdown]
# ##### 4. 1 Fast method

# %%
var = 0.99
model = PCA(n_components=var)
Xpca = model.fit_transform(X)

# %%
Xpca.shape #41 components
model.n_components_ #41 components
# Out:
# 41

# %% [markdown]
# #### 5. Dimension Reduction (Sequential Data or Time Series Analysis)

# %%
import scipy.io as scio

# %%
Xsim_data = scio.loadmat(r"DataLinearSlope.mat")
Xsim_data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Sun Nov 28 20:16:31 2021',
#  '__version__': '1.0',
#  '__globals__': [],
#  'X': array([[-1.92014911e+00,  6.97155491e-01, -2.02236259e-01, ...,
#          -6.57544820e-01,  2.90534445e+00, -1.05341705e-01],
#         [-1.92014911e+00,  6.98155491e-01, -2.00236259e-01, ...,
#          -1.60544820e-01,  3.40334445e+00,  3.93658295e-01],
#         [-1.92014911e+00,  6.99155491e-01, -1.98236259e-01, ...,
#           3.36455180e-01,  3.90134445e+00,  8.92658295e-01],
#         ...,
#         [-1.92014911e+00,  1.69515549e+00,  1.79376374e+00, ...,
#           4.95348455e+02,  4.99909344e+02,  4.97896658e+02],
#         [-1.92014911e+00,  1.69615549e+00,  1.79576374e+00, ...,
#           4.95845455e+02,  5.00407344e+02,  4.98395658e+02],
#         [-1.92014911e+00,  1.69715549e+00,  1.79776374e+00, ...,
#           4.96342455e+02,  5.00905344e+02,  4.98894658e+02]]),
#  'target': array([[  1. ],
#         [  1.5],
#         [  2. ],
#         ...,
#         [500. ],
#         [500.5],
#         [501. ]])}

# %%
X = Xsim_data['X']
y = Xsim_data['target']

# %%
print("Shape X:",X.shape)
# Out:
# Shape X: (1001, 500)

# %%
plt.figure(figsize=(15,15))
plt.plot(X);

# %%
n_component = X.shape[1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0,test_size=0.2)

# %%
preprocessor = make_pipeline(StandardScaler(),PCA(n_components = 0.99,random_state=0))

# %%
X_train_pca = preprocessor.fit_transform(X_train,y_train)
X_test_pca = preprocessor.transform(X_test)
X_train_pca.shape
# Out:
# (800, 1)

# %%
plt.figure(figsize=(5,5))
CompInit = 0
CompFinal = 0
plt.scatter(X_train_pca[:,CompInit],X_train_pca[:,CompFinal],c = y_train);
plt.colorbar();
plt.figure(figsize=(5,5))
plt.scatter(X_test_pca[:,CompInit],X_test_pca[:,CompFinal],c=y_test)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">

# %%
import xgboost as xgb
model = xgb.XGBRegressor()

# %%
model.fit(X_train_pca,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=4,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
model.score(X_test_pca,y_test)
# Out:
# 0.9999767589192755

# %%
X_measure = scio.loadmat(r"measLinearSlope.mat")['x']
X_measure
# Out:
# array([[ -1.92014911,   1.29545549,   0.99436374,   3.12216278,
#           4.7154201 ,   1.16272182,   1.66075128,   5.11429555,
#           4.56076875,   5.42849747,   4.23187179,   4.70612887,
#           8.09719202,  10.9241929 ,   7.71116845,  11.2208398 ,
#          12.3442237 ,  12.34909638,  13.83823235,  12.12326126,
#           8.77751444,  10.95876242,  12.89748066,  10.90300154,
#          13.35879034,  17.5568937 ,  14.04685408,  16.61405967,
#          17.37096685,  21.09919353,  17.50535344,  19.90002185,
#          16.74690339,  18.05561655,  21.06329917,  22.05920563,
#          20.6664647 ,  22.76056821,  21.46593601,  24.56019823,
#          22.60730484,  25.11489832,  25.91742579,  28.67866204,
#          24.19429247,  27.44101748,  24.16098591,  28.46776628,
#          30.38302228,  27.28033459,  29.6047111 ,  33.07253484,
#          34.52717886,  31.8199983 ,  35.3878521 ,  32.69939447,
#          31.86892958,  34.00941832,  31.33219852,  33.76519126,
#          34.77555277,  39.3751564 ,  37.66370981,  41.90718399,
#          39.30946769,  39.72677341,  39.17233414,  38.43701849,
#          41.1593426 ,  40.66842207,  38.90649318,  43.65117385,
#          42.89161797,  44.34589603,  43.38140826,  46.39329246,
#          44.42572492,  46.93467219,  48.1597831 ,  47.17299856,
#          46.18326292,  49.10158006,  51.37898618,  45.46882422,
#          50.65320979,  51.30777486,  52.32570682,  51.46874806,
#          53.50276239,  52.31852314,  54.53759445,  56.92357736,
#          55.04606166,  53.66945655,  56.22145721,  57.89669201,
#          57.08835132,  61.55166052,  57.94706133,  58.579545  ,
#          63.2893316 ,  61.22758101,  62.30121875,  64.49817014,
#          61.12083162,  62.66009876,  65.37078269,  62.6387801 ,
#          65.31012322,  63.1058733 ,  67.05163398,  71.10461805,
#          66.90852471,  67.02936647,  71.75637078,  67.15849058,
#          68.88161599,  70.16951927,  72.04939011,  69.25761436,
#          70.10044716,  73.24518103,  72.85831729,  70.48488685,
#          70.99000161,  71.57324993,  75.67741944,  77.14436615,
#          78.17253693,  75.31472463,  74.01732118,  79.8237629 ,
#          79.07118946,  79.80440658,  79.62800987,  80.41737215,
#          85.44430984,  81.9334006 ,  83.86297686,  79.09910451,
#          81.06731709,  83.07889283,  85.53618559,  86.56621657,
#          91.46277168,  83.52883298,  84.18750697,  87.68173795,
#          87.10555078,  87.36752979,  91.95078781,  89.79194368,
#          92.18264323,  92.25279056,  89.24489043,  94.57822251,
#          93.13418836,  92.92278991,  94.5410268 ,  96.2343899 ,
#          98.25791716,  96.85247939,  93.79924189,  99.5175534 ,
#          97.35624435, 102.73991001, 100.86986774, 101.55839357,
#         100.16834659,  99.76419975, 100.59119983, 100.05807191,
#         101.60424515, 106.21575437, 103.2556815 , 104.93335665,
#         108.76757085, 105.25568001, 106.45050547, 108.83637467,
#         108.45282129, 109.57950352, 108.49788173, 109.50111239,
#         113.69500132, 115.09848287, 111.58708195, 110.707974  ,
#         112.67474427, 112.30185167, 112.61989647, 110.70854108,
#         112.15741442, 115.79914922, 115.16401619, 119.70306599,
#         113.95638818, 116.40171942, 119.86491846, 120.39770822,
#         119.17957617, 118.65343776, 116.5181079 , 120.90925001,
#         123.40028171, 122.8195665 , 120.92340953, 126.17361247,
#         126.33633057, 125.08196855, 126.22740847, 126.81059977,
#         127.62036189, 129.40758476, 127.74355633, 132.24248249,
#         127.37531664, 129.62119715, 129.26365121, 130.13421514,
#         128.76212835, 134.99777401, 133.41916348, 133.61306251,
#         134.65963063, 133.64598889, 134.92789275, 138.06284741,
#         136.73526473, 138.49074421, 139.37973086, 140.72562031,
#         138.19965553, 138.37937985, 141.22909264, 139.18483997,
#         144.02198891, 140.12442392, 145.05462999, 146.72459827,
#         141.49500735, 147.03652729, 146.31057002, 146.10421519,
#         145.99726995, 146.70209661, 149.43963809, 146.98069728,
#         147.65480807, 155.65532705, 153.25799164, 152.84981015,
#         153.19161663, 151.82515258, 148.99709957, 152.6944438 ,
#         155.1996765 , 155.6202133 , 158.08626923, 157.92202663,
#         156.98565415, 155.57484613, 156.71325737, 158.90013531,
#         157.53718403, 158.18998626, 162.58854424, 160.01253816,
#         157.71792379, 157.09519715, 162.57138659, 161.72317961,
#         162.48675943, 163.60266068, 164.55666518, 163.04429143,
#         165.63210627, 161.89177166, 165.01565185, 166.69537073,
#         168.6387764 , 169.23992755, 171.8181117 , 173.24954561,
#         171.3751204 , 169.43235049, 172.7523191 , 174.79148306,
#         175.14290203, 173.69165743, 171.17579196, 172.10987063,
#         174.55539018, 176.92914094, 175.30938519, 173.95084105,
#         180.33077976, 177.38397704, 180.89014701, 180.36390859,
#         177.47948524, 180.80058629, 182.63833285, 180.51943692,
#         181.10256655, 183.732152  , 181.61610559, 182.92871771,
#         187.54401713, 184.80504145, 187.00231557, 185.71567489,
#         184.20627546, 186.93701478, 187.37113053, 189.49666118,
#         188.68870624, 192.31588323, 186.78378588, 192.27368011,
#         191.03155591, 194.62549462, 193.43308861, 197.16060905,
#         193.68016824, 194.46247736, 196.64830653, 198.4050692 ,
#         194.4825304 , 192.19860831, 197.71817253, 199.19711902,
#         202.3459734 , 199.37850567, 200.68382842, 202.44144671,
#         200.46384776, 200.2731071 , 202.44155837, 199.9484116 ,
#         205.11309061, 202.62959375, 202.19138274, 206.01998076,
#         207.45999656, 206.63443706, 208.7656039 , 209.81245839,
#         210.26813373, 209.08885911, 210.63569482, 209.60075954,
#         214.32498716, 210.46595486, 210.20108125, 211.85414576,
#         212.31827649, 211.75000107, 212.35351074, 218.96637488,
#         216.24226632, 214.86076649, 219.44281536, 215.99200751,
#         221.57767498, 218.5262419 , 218.17249247, 222.95070096,
#         219.79499046, 221.52858868, 223.56532111, 223.29206172,
#         222.033501  , 219.69931436, 222.94799055, 226.4774946 ,
#         227.86563329, 226.80436734, 228.76762671, 228.1593285 ,
#         231.01850579, 231.71256421, 228.14797014, 229.95522212,
#         231.71775186, 233.68215014, 232.01110403, 231.28643494,
#         232.85659197, 230.85074909, 233.05259776, 232.99823257,
#         235.68221091, 235.42963635, 238.80952762, 237.51136435,
#         235.45173082, 239.19762142, 236.92897544, 239.93433294,
#         245.01051812, 239.84501535, 241.7239313 , 244.21252483,
#         240.49101614, 245.63014618, 242.9201446 , 245.98749019,
#         243.8548056 , 248.98411987, 248.50939361, 245.35104661,
#         250.98201967, 247.36502113, 250.13741623, 249.48025456,
#         249.71505502, 254.38708982, 247.84816537, 248.49080825,
#         253.74976165, 248.39917247, 254.96991081, 256.54093292,
#         251.55439533, 255.06244786, 254.53027419, 258.19345858,
#         255.66186352, 259.13627759, 256.60039071, 260.88409704,
#         260.0752272 , 257.55812365, 258.22800764, 261.2437975 ,
#         257.77470133, 264.16259451, 265.88431742, 264.85439542,
#         261.83705121, 265.21327109, 269.80801292, 268.44826097,
#         267.62479549, 268.88172769, 270.42062901, 268.7182509 ,
#         268.72136781, 268.99514695, 270.45806349, 270.27074401,
#         269.80736837, 270.07658314, 273.75193424, 272.00627815,
#         271.85444225, 271.59442627, 272.19027023, 276.91091727,
#         275.40989085, 277.97640211, 279.7694099 , 277.40524021,
#         279.99010482, 284.93140334, 279.06906541, 281.23531929,
#         280.32945322, 283.77459584, 281.34055341, 281.90699383,
#         284.66755858, 283.89839445, 283.17292574, 280.80886575,
#         282.9270608 , 285.26178534, 288.52002687, 288.94155314,
#         289.23637415, 290.79994777, 288.94585851, 290.70804253,
#         290.42149149, 292.04396145, 291.37480088, 294.41164904,
#         289.82302596, 298.27054875, 293.60648929, 292.28308928,
#         293.05754168, 295.86536299, 299.15180018, 295.26188853,
#         298.58684655, 296.69755518, 300.85874445, 298.4463583 ]])

# %%
X_measure_pca = preprocessor.transform(X_measure)

# %%
y_predicted = model.predict(X_measure_pca)
print(y_predicted)
plt.figure(figsize=(5,5))
plt.scatter(X_train_pca[:,CompInit],X_train_pca[:,CompFinal],c=y_train)
plt.colorbar()
plt.scatter(X_measure_pca[:,CompInit],X_measure_pca[:,CompFinal],c='r')
# Out:
# [298.81937]
# <img src="data:image/png;base64,..." width="500">
